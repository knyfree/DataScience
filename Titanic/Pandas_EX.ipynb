# %%
import pandas as pd

# %%
#train = pd.read_csv("C:/Users/P069311/Desktop/Data_Analysis/Titanic/data/train.csv", index_col="PassengerId")
train = pd.read_csv("./data/train.csv",index_col="PassengerId")
print(train.shape)
train.head()
# Out:
# (891, 11)
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train.columns
# Out:
# Index(['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
#        'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
train.tail()
# Out:
#              Survived  Pclass                                      Name  \
# PassengerId
# 887                 0       2                     Montvila, Rev. Juozas
# 888                 1       1              Graham, Miss. Margaret Edith
# 889                 0       3  Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                     Behr, Mr. Karl Howell
# 891                 0       3                       Dooley, Mr. Patrick
#
#                 Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# PassengerId
# 887            male  27.0      0      0      211536  13.00   NaN        S
# 888          female  19.0      0      0      112053  30.00   B42        S
# 889          female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 890            male  26.0      0      0      111369  30.00  C148        C
# 891            male  32.0      0      0      370376   7.75   NaN        Q

# %%
train[["Sex","Name","Age"]].head()
# Out:
#                 Sex                                               Name   Age
# PassengerId
# 1              male                            Braund, Mr. Owen Harris  22.0
# 2            female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3            female                             Heikkinen, Miss. Laina  26.0
# 4            female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5              male                           Allen, Mr. William Henry  35.0

# %%
feature_name = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 
                'Ticket', 'Fare', 'Cabin', 'Embarked']

train[feature_name].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train.loc[1:9]
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# 6                                             Moran, Mr. James    male   NaN
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 7                0      0             17463  51.8625   E46        S
# 8                3      1            349909  21.0750   NaN        S
# 9                0      2            347742  11.1333   NaN        S

# %%
train.loc[1:7,["Sex","Name","Age"]]
# Out:
#                 Sex                                               Name   Age
# PassengerId
# 1              male                            Braund, Mr. Owen Harris  22.0
# 2            female  Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 3            female                             Heikkinen, Miss. Laina  26.0
# 4            female       Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 5              male                           Allen, Mr. William Henry  35.0
# 6              male                                   Moran, Mr. James   NaN
# 7              male                            McCarthy, Mr. Timothy J  54.0

# %%
train[train["Sex"] == "male"].head()
# Out:
#              Survived  Pclass                            Name   Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris  male  22.0
# 5                   0       3        Allen, Mr. William Henry  male  35.0
# 6                   0       3                Moran, Mr. James  male   NaN
# 7                   0       1         McCarthy, Mr. Timothy J  male  54.0
# 8                   0       3  Palsson, Master. Gosta Leonard  male   2.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 5                0      0     373450   8.0500   NaN        S
# 6                0      0     330877   8.4583   NaN        Q
# 7                0      0      17463  51.8625   E46        S
# 8                3      1     349909  21.0750   NaN        S

# %%
train_fare = train["Fare"] > 20

# %%
train[train_fare].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 2                   1       1
# 4                   1       1
# 7                   0       1
# 8                   0       3
# 10                  1       2
#
#                                                           Name     Sex   Age  \
# PassengerId
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 7                                      McCarthy, Mr. Timothy J    male  54.0
# 8                               Palsson, Master. Gosta Leonard    male   2.0
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female  14.0
#
#              SibSp  Parch    Ticket     Fare Cabin Embarked
# PassengerId
# 2                1      0  PC 17599  71.2833   C85        C
# 4                1      0    113803  53.1000  C123        S
# 7                0      0     17463  51.8625   E46        S
# 8                3      1    349909  21.0750   NaN        S
# 10               1      0    237736  30.0708   NaN        C

# %%
#train[train["Embarked"] != "C"].head()

# %%
train[train["Embarked"].isin(["Q","S"])].head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
# 6              male   NaN      0      0            330877   8.4583   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 3                  S
# 4                  S
# 5                  S
# 6                  Q

# %%
not_cherbourg = ["Q", "S"]
embarked_isin = train["Embarked"].isin(not_cherbourg)
train[embarked_isin].head()
# Out:
#              Survived  Pclass                                          Name  \
# PassengerId
# 1                   0       3                       Braund, Mr. Owen Harris
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# 6                   0       3                              Moran, Mr. James
#
#                 Sex   Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1              male  22.0      1      0         A/5 21171   7.2500   NaN
# 3            female  26.0      0      0  STON/O2. 3101282   7.9250   NaN
# 4            female  35.0      1      0            113803  53.1000  C123
# 5              male  35.0      0      0            373450   8.0500   NaN
# 6              male   NaN      0      0            330877   8.4583   NaN
#
#             Embarked
# PassengerId
# 1                  S
# 3                  S
# 4                  S
# 5                  S
# 6                  Q

# %%
not_first_class = ~(train["Pclass"] == 1)
train[not_first_class].head()
# Out:
#              Survived  Pclass                            Name     Sex   Age  \
# PassengerId
# 1                   0       3         Braund, Mr. Owen Harris    male  22.0
# 3                   1       3          Heikkinen, Miss. Laina  female  26.0
# 5                   0       3        Allen, Mr. William Henry    male  35.0
# 6                   0       3                Moran, Mr. James    male   NaN
# 8                   0       3  Palsson, Master. Gosta Leonard    male   2.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 5                0      0            373450   8.0500   NaN        S
# 6                0      0            330877   8.4583   NaN        Q
# 8                3      1            349909  21.0750   NaN        S

# %%
train[train["Pclass"]==1 & train["Age"].isnull()].head()
# Out:
#              Survived  Pclass                                            Name  \
# PassengerId
# 32                  1       1  Spencer, Mrs. William Augustus (Marie Eugenie)
# 56                  1       1                               Woolner, Mr. Hugh
# 65                  0       1                           Stewart, Mr. Albert A
# 167                 1       1          Chibnall, Mrs. (Edith Martha Bowerman)
# 169                 0       1                             Baumann, Mr. John D
#
#                 Sex  Age  SibSp  Parch    Ticket      Fare Cabin Embarked
# PassengerId
# 32           female  NaN      1      0  PC 17569  146.5208   B78        C
# 56             male  NaN      0      0     19947   35.5000   C52        S
# 65             male  NaN      0      0  PC 17605   27.7208   NaN        C
# 167          female  NaN      0      1    113505   55.0000   E33        S
# 169            male  NaN      0      0  PC 17318   25.9250   NaN        S

# %%
train[(train["SibSp"] == 0) & (train["Parch"] == 0)].head()
# Out:
#              Survived  Pclass                      Name     Sex   Age  SibSp  \
# PassengerId
# 3                   1       3    Heikkinen, Miss. Laina  female  26.0      0
# 5                   0       3  Allen, Mr. William Henry    male  35.0      0
# 6                   0       3          Moran, Mr. James    male   NaN      0
# 7                   0       1   McCarthy, Mr. Timothy J    male  54.0      0
# 12                  1       1  Bonnell, Miss. Elizabeth  female  58.0      0
#
#              Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 3                0  STON/O2. 3101282   7.9250   NaN        S
# 5                0            373450   8.0500   NaN        S
# 6                0            330877   8.4583   NaN        Q
# 7                0             17463  51.8625   E46        S
# 12               0            113783  26.5500  C103        S

# %%
without_sibsp = train["SibSp"] == 0
without_parch = train["Parch"] == 0

train[without_sibsp | without_parch].head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train.loc[train["Sex"] == "male", ["SibSp", "Parch", "FamilySize"]].head()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py:1367: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#              SibSp  Parch  FamilySize
# PassengerId
# 1                1      0         NaN
# 5                0      0         NaN
# 6                0      0         NaN
# 7                0      0         NaN
# 8                3      1         NaN

# %%
train.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
train["prev_Age"] = train["Age"].shift(+1)

# %%
train["prev_Age"].head()
# Out:
# PassengerId
# 1     NaN
# 2    22.0
# 3    38.0
# 4    26.0
# 5    35.0
# Name: prev_Age, dtype: float64

# %%
pd.crosstab(index=train["Embarked"], columns=train["Survived"])
# Out:
# Survived    0    1
# Embarked
# C          75   93
# Q          47   30
# S         427  217

# %%
pd.crosstab(index=[train["Sex"], train["Embarked"]], columns=train["Fare"])
# Out:
# Fare             0.0000    4.0125    5.0000    6.2375    6.4375    6.4500    \
# Sex    Embarked
# female C                0         0         0         0         0         0
#        Q                0         0         0         0         0         0
#        S                0         0         0         0         0         0
# male   C                0         1         0         0         1         0
#        Q                0         0         0         0         0         0
#        S               15         0         1         1         0         1
#
# Fare             6.4958    6.7500    6.8583    6.9500      ...     153.4625  \
# Sex    Embarked                                            ...
# female C                0         0         0         0    ...            0
#        Q                0         1         0         0    ...            0
#        S                0         0         0         0    ...            2
# male   C                0         0         0         0    ...            0
#        Q                0         1         1         1    ...            0
#        S                2         0         0         0    ...            1
#
# Fare             164.8667  211.3375  211.5000  221.7792  227.5250  247.5208  \
# Sex    Embarked
# female C                0         0         0         0         3         1
#        Q                0         0         0         0         0         0
#        S                2         3         0         0         0         0
# male   C                0         0         1         0         1         1
#        Q                0         0         0         0         0         0
#        S                0         0         0         1         0         0
#
# Fare             262.3750  263.0000  512.3292
# Sex    Embarked
# female C                2         0         1
#        Q                0         0         0
#        S                0         2         0
# male   C                0         0         2
#        Q                0         0         0
#        S                0         2         0
#
# [6 rows x 247 columns]

# %%
import numpy as np
pd.crosstab(index=[train["Sex"], train["Embarked"]], columns=[], values=train["Fare"], aggfunc=np.mean)
# Out:
#                  __dummy__
# Sex    Embarked
# female C         75.169805
#        Q         12.634958
#        S         38.740929
# male   C         48.262109
#        Q         13.838922
#        S         21.711996

# %%
pd.crosstab(index=[train["Sex"], train["Embarked"]], columns=["운임요금(Fare)"], values=train["Fare"], aggfunc=np.mean)
# Out:
# col_0            운임요금(Fare)
# Sex    Embarked
# female C          75.169805
#        Q          12.634958
#        S          38.740929
# male   C          48.262109
#        Q          13.838922
#        S          21.711996

# %%
pd.pivot_table(train, index="Sex", values="Survived")
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %%
pd.pivot_table(train, index=["Sex", "Embarked"], values="Survived")
# Out:
#                  Survived
# Sex    Embarked
# female C         0.876712
#        Q         0.750000
#        S         0.689655
# male   C         0.305263
#        Q         0.073171
#        S         0.174603

# %%
pd.pivot_table(train, index=["Sex", "Embarked"], values="Fare")
# Out:
#                       Fare
# Sex    Embarked
# female C         75.169805
#        Q         12.634958
#        S         38.740929
# male   C         48.262109
#        Q         13.838922
#        S         21.711996

# %%
pd.pivot_table(train, index=["Sex", "Embarked"], values="Fare", aggfunc=np.sum)
# Out:
#                       Fare
# Sex    Embarked
# female C         5487.3958
#        Q          454.8585
#        S         7864.4085
# male   C         4584.9004
#        Q          567.3958
#        S         9574.9903

# %%
train["Category"] = "Titanic"

# %%
train[["Category"]].head()
# Out:
#             Category
# PassengerId
# 1            Titanic
# 2            Titanic
# 3            Titanic
# 4            Titanic
# 5            Titanic

# %%
train["Id"] = range(891)
train[["Id"]].head()
# Out:
#              Id
# PassengerId
# 1             0
# 2             1
# 3             2
# 4             3
# 5             4

# %%
train["FamilySize"] = train["SibSp"] + train["Parch"] + 1

train[["SibSp", "Parch", "FamilySize"]].head()
# Out:
#              SibSp  Parch  FamilySize
# PassengerId
# 1                1      0           2
# 2                1      0           2
# 3                0      0           1
# 4                1      0           2
# 5                0      0           1

# %%
train["Nationality_FR"] = train["Embarked"] =="C"
train["Nationality_UK"] = train["Embarked"] !="C"

train[["Embarked", "Nationality_FR", "Nationality_UK"]].head()
# Out:
#             Embarked  Nationality_FR  Nationality_UK
# PassengerId
# 1                  S           False            True
# 2                  C            True           False
# 3                  S           False            True
# 4                  S           False            True
# 5                  S           False            True

# %%
train.loc[train["Embarked"] == "C", "Nationality"] = "France"
train.loc[train["Embarked"] != "C", "Nationality"] = "England"

train[["Embarked", "Nationality"]].head()
# Out:
#             Embarked Nationality
# PassengerId
# 1                  S     England
# 2                  C      France
# 3                  S     England
# 4                  S     England
# 5                  S     England

# %%
train["Fare_Cheap"] = train["Fare"] < 30
train["Fare_Medium"] = (train["Fare"] >= 30) & (train["Fare"] < 100)
train["Fare_Expensive"] = train["Fare"] >= 100

train[["Fare", "Fare_Cheap", "Fare_Medium", "Fare_Expensive"]].head()
# Out:
#                 Fare  Fare_Cheap  Fare_Medium  Fare_Expensive
# PassengerId
# 1             7.2500        True        False           False
# 2            71.2833       False         True           False
# 3             7.9250        True        False           False
# 4            53.1000       False         True           False
# 5             8.0500        True        False           False

# %%
train.loc[train["Fare"] < 30, "FareType"] = "Cheap"
train.loc[(train["Fare"] >= 30) & (train["Fare"] < 100), "FareType"] = "Medium"
train.loc[train["Fare"] >= 100, "FareType"] = "Expensive"
train[["Fare","FareType"]].head()
# Out:
#                 Fare FareType
# PassengerId
# 1             7.2500    Cheap
# 2            71.2833   Medium
# 3             7.9250    Cheap
# 4            53.1000   Medium
# 5             8.0500    Cheap

# %%
mean_age = train["Age"].mean()
print(mean_age)
train.loc[train["Age"].isnull(), "Age"] = mean_age

train.head(20)
# Out:
# 29.69911764705882
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# 6                   0       3
# 7                   0       1
# 8                   0       3
# 9                   1       3
# 10                  1       2
# 11                  1       3
# 12                  1       1
# 13                  0       3
# 14                  0       3
# 15                  0       3
# 16                  1       2
# 17                  0       3
# 18                  1       2
# 19                  0       3
# 20                  1       3
#
#                                                           Name     Sex  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 3                                       Heikkinen, Miss. Laina  female
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 5                                     Allen, Mr. William Henry    male
# 6                                             Moran, Mr. James    male
# 7                                      McCarthy, Mr. Timothy J    male
# 8                               Palsson, Master. Gosta Leonard    male
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 10                         Nasser, Mrs. Nicholas (Adele Achem)  female
# 11                             Sandstrom, Miss. Marguerite Rut  female
# 12                                    Bonnell, Miss. Elizabeth  female
# 13                              Saundercock, Mr. William Henry    male
# 14                                 Andersson, Mr. Anders Johan    male
# 15                        Vestrom, Miss. Hulda Amanda Adolfina  female
# 16                            Hewlett, Mrs. (Mary D Kingcome)   female
# 17                                        Rice, Master. Eugene    male
# 18                                Williams, Mr. Charles Eugene    male
# 19           Vander Planke, Mrs. Julius (Emelia Maria Vande...  female
# 20                                     Masselmani, Mrs. Fatima  female
#
#                    Age  SibSp  Parch            Ticket     Fare Cabin  \
# PassengerId
# 1            22.000000      1      0         A/5 21171   7.2500   NaN
# 2            38.000000      1      0          PC 17599  71.2833   C85
# 3            26.000000      0      0  STON/O2. 3101282   7.9250   NaN
# 4            35.000000      1      0            113803  53.1000  C123
# 5            35.000000      0      0            373450   8.0500   NaN
# 6            29.699118      0      0            330877   8.4583   NaN
# 7            54.000000      0      0             17463  51.8625   E46
# 8             2.000000      3      1            349909  21.0750   NaN
# 9            27.000000      0      2            347742  11.1333   NaN
# 10           14.000000      1      0            237736  30.0708   NaN
# 11            4.000000      1      1           PP 9549  16.7000    G6
# 12           58.000000      0      0            113783  26.5500  C103
# 13           20.000000      0      0         A/5. 2151   8.0500   NaN
# 14           39.000000      1      5            347082  31.2750   NaN
# 15           14.000000      0      0            350406   7.8542   NaN
# 16           55.000000      0      0            248706  16.0000   NaN
# 17            2.000000      4      1            382652  29.1250   NaN
# 18           29.699118      0      0            244373  13.0000   NaN
# 19           31.000000      1      0            345763  18.0000   NaN
# 20           29.699118      0      0              2649   7.2250   NaN
#
#                ...    Category  Id FamilySize  Nationality_FR  Nationality_UK  \
# PassengerId    ...
# 1              ...     Titanic   0          2           False            True
# 2              ...     Titanic   1          2            True           False
# 3              ...     Titanic   2          1           False            True
# 4              ...     Titanic   3          2           False            True
# 5              ...     Titanic   4          1           False            True
# 6              ...     Titanic   5          1           False            True
# 7              ...     Titanic   6          1           False            True
# 8              ...     Titanic   7          5           False            True
# 9              ...     Titanic   8          3           False            True
# 10             ...     Titanic   9          2            True           False
# 11             ...     Titanic  10          3           False            True
# 12             ...     Titanic  11          1           False            True
# 13             ...     Titanic  12          1           False            True
# 14             ...     Titanic  13          7           False            True
# 15             ...     Titanic  14          1           False            True
# 16             ...     Titanic  15          1           False            True
# 17             ...     Titanic  16          6           False            True
# 18             ...     Titanic  17          1           False            True
# 19             ...     Titanic  18          2           False            True
# 20             ...     Titanic  19          1            True           False
#
#              Nationality  Fare_Cheap Fare_Medium  Fare_Expensive  FareType
# PassengerId
# 1                England        True       False           False     Cheap
# 2                 France       False        True           False    Medium
# 3                England        True       False           False     Cheap
# 4                England       False        True           False    Medium
# 5                England        True       False           False     Cheap
# 6                England        True       False           False     Cheap
# 7                England       False        True           False    Medium
# 8                England        True       False           False     Cheap
# 9                England        True       False           False     Cheap
# 10                France       False        True           False    Medium
# 11               England        True       False           False     Cheap
# 12               England        True       False           False     Cheap
# 13               England        True       False           False     Cheap
# 14               England       False        True           False    Medium
# 15               England        True       False           False     Cheap
# 16               England        True       False           False     Cheap
# 17               England        True       False           False     Cheap
# 18               England        True       False           False     Cheap
# 19               England        True       False           False     Cheap
# 20                France        True       False           False     Cheap
#
# [20 rows x 22 columns]

# %%
columns = ['Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp', 'Parch', 'Ticket',
           'Fare', 'Cabin', 'Embarked', 'Category', 'Id',
           'FamilySize']

train = train[columns]

train.head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked Category  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S  Titanic
# 2                1      0          PC 17599  71.2833   C85        C  Titanic
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S  Titanic
# 4                1      0            113803  53.1000  C123        S  Titanic
# 5                0      0            373450   8.0500   NaN        S  Titanic
#
#              Id  FamilySize
# PassengerId
# 1             0           2
# 2             1           2
# 3             2           1
# 4             3           2
# 5             4           1

# %%
train.drop("Category", axis=1).head()
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  Id  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S   0
# 2                1      0          PC 17599  71.2833   C85        C   1
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S   2
# 4                1      0            113803  53.1000  C123        S   3
# 5                0      0            373450   8.0500   NaN        S   4
#
#              FamilySize
# PassengerId
# 1                     2
# 2                     2
# 3                     1
# 4                     2
# 5                     1

# %%
def recognize_title(name):
    if "Miss" in name:
        return "Miss"
    elif "Mrs" in name:
        return "Mrs"
    elif "Mr" in name:
        return "Mr"
    elif "Master" in name:
        return "Master"
    else:
        return "Others"
    
train["Title"] = train["Name"].apply(recognize_title)

train[["Name", "Title"]].head(10)
# Out:
#                                                           Name   Title
# PassengerId
# 1                                      Braund, Mr. Owen Harris      Mr
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...     Mrs
# 3                                       Heikkinen, Miss. Laina    Miss
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)     Mrs
# 5                                     Allen, Mr. William Henry      Mr
# 6                                             Moran, Mr. James      Mr
# 7                                      McCarthy, Mr. Timothy J      Mr
# 8                               Palsson, Master. Gosta Leonard  Master
# 9            Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)     Mrs
# 10                         Nasser, Mrs. Nicholas (Adele Achem)     Mrs

# %%
train.to_csv("./data/train_modified.csv")

# %%
train = pd.read_csv("./data/train_modified.csv")
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Category  Id  FamilySize  \
# 0      0         A/5 21171   7.2500   NaN        S  Titanic   0           2
# 1      0          PC 17599  71.2833   C85        C  Titanic   1           2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Titanic   2           1
# 3      0            113803  53.1000  C123        S  Titanic   3           2
# 4      0            373450   8.0500   NaN        S  Titanic   4           1
#
#   Title
# 0    Mr
# 1   Mrs
# 2  Miss
# 3   Mrs
# 4    Mr
